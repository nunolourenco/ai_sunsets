# %% [markdown]
# <div style="width: 100%; overflow: hidden;">
#     <a href="https://www.cisuc.uc.pt/groups/show/ecos">
#     <div style="float: left;"><img src="https://eden.dei.uc.pt/~naml/images_ecos/ecos.png" width="250px" /></div>
#     </a>
#     <a href="http://www.uc.pt/fctuc/dei/">
#     <div style="float: right;"><img src="https://eden.dei.uc.pt/~naml/images_ecos/dei25.png" width="700px" /></div>
#     </a>
# </div>

# %% [markdown]
# # Imports

# %%
import sys
import random
import copy
import json
import numpy as np

# %% [markdown]
# # Parameters

# %%
# CONFIG
POPULATION_SIZE = 100
NUMBER_OF_ITERATIONS = 500
TOURNAMENT = 4
PROB_CROSSOVER = 0.9
PROB_MUTATION = 0.05
INVALID_FITNESS = sys.maxsize # ASSUMES MINIMIZATION
SEED = 42
GENOTYPE_SIZE = len(TARGET_STRING)
# The options available for the genotype
OPTIONS = list(range(65, 91)) + [32]
# TARGET STRING.
TARGET_STRING = "METHINKS IT IS LIKE A WEASEL"

# %% [markdown]
# # Fitness evaluation

# %%
def fitness(individual):
    """ Computes the number of positions between the phenotype and the target string"""
    different_pos = 0
    individual = individual.upper()
    for i in range(len(TARGET_STRING)):
        if individual[i] != TARGET_STRING[i]:
            different_pos += 1
    return different_pos

def evaluate(ind):
    pheno = mapping(ind['genotype'])
    ind['fitness'] = fitness(pheno)

# %% [markdown]
# # Generate a Random Invidiual

# %%
def generate_random_individual():
    # randint of upper case chars 
    genotype = [ random.choice(OPTIONS) for c in range(GENOTYPE_SIZE) ]
    return {'genotype': genotype, 'fitness': None }

# %% [markdown]
# # Generate Initial Population

# %%
def generate_initial_population():
    for i in range(POPULATION_SIZE):
        yield generate_random_individual()

# %% [markdown]
# # Mapping
#
# Convert the genotype into the phenotype, i.e. a string

# %%
def mapping(genotype):
    sentence = ""
    for value in genotype:
        sentence += chr(value)
    return sentence

# %% [markdown]
# # Parent Selection
#
# Selection of an individual using Tournament Selection

# %%
def choose_indiv(population):
    pool = random.sample(population, TOURNAMENT)
    pool.sort(key=lambda i: i['fitness'])
    return copy.deepcopy(pool[0])

# %% [markdown]
# # Recombination

# %%
def crossover(p1, p2):
    at = random.randint(0, len(p1['genotype'])-1)
    genotype = []
    for i in range(len(p1['genotype'])):
        if i < at:
            genotype.append(p1['genotype'][i])
        else:
            genotype.append(p2['genotype'][i])
    return {'genotype': genotype, 'fitness': None}

# %% [markdown]
# # Mutation

# %%
def mutate(p):
    p = copy.deepcopy(p)
    p['fitness'] = None
    at = random.randint(0, len(p['genotype'])-1)
    p['genotype'][at] = random.choice(OPTIONS)
    return p

# %% [markdown]
# # Evolutionary Cycle

# %%
def main():
    bests = []
    # Create a initial population randomly
    population = list(generate_initial_population())
    it = 0
    #Evaluate how good the individuals are (problem dependent)
    for it in range(it, NUMBER_OF_ITERATIONS):
        for i in population:
            if i['fitness'] == None:
                evaluate(i)
        population.sort(key = lambda x: x['fitness'])
        best = (mapping(population[0]['genotype']), population[0]['fitness'])
        bests.append(best)
        # print("Best at", it, best[1])
        print("Best at", it, best[0])
        new_population = []
        while len(new_population) < POPULATION_SIZE:
            if random.random() < PROB_CROSSOVER:
                #Parent Selection
                p1 = choose_indiv(population)
                p2 = choose_indiv(population)
                #Recombination
                ni = crossover(p1, p2)
            else:
                ni = choose_indiv(population)
            #Mutation 
            if random.random() < PROB_MUTATION:
                ni = mutate(ni)
            new_population.append(ni)
        population = new_population
    print(bests[-1])

# %%
random.seed(SEED)
main()
# Out:
# Best at 0 METWCJRMUZK EVW XVQCUVNQLALJ
# Best at 1 METWCJRMUZK EVW XVQCUVNOEIEH
# Best at 2 METWCOIFSNU PCPLXSIKH CIOHYO
# Best at 3 METWYULMUZK EJ PW EYWPOTACAI
# Best at 4 METWYULMUZK EJ PW ESAYV ISBY
# Best at 5 METHOSTKYOT PCPLNKSSAYV ISBY
# Best at 6 METHOSTKYOT PCPLNKSSAYV ISBY
# Best at 7 METHOSTKYOT PCPLNKSSAYV ISBY
# Best at 8 METHOSKKYOT PCPLNKSSAYV ISBY
# Best at 9 METHOSTKYOT PCPLNKSSAYVTASBY
# Best at 10 METHOSKKYOT PCPLNKSSAYV ASBY
# Best at 11 METHOSKKYOT PCPLNKESAYV ISEH
# Best at 12 METHOSKKYOT PCPLNKESAYV ISEH
# Best at 13 METHOSKKYOT PCPLNKESAYVTASEH
# Best at 14 METHOSKKYOT PCPLNKESAYVTASEH
# Best at 15 METHOSKKYOT PCPLNKESAYVTASEH
# Best at 16 METHOSKKYOT PJ LNKESAYV ASEH
# Best at 17 METHOSKKYOT PJ LNKESAJP ASEH
# Best at 18 METHOSKKYOT PJ LNKESAYVTASEH
# Best at 19 METHOSKKYOT PJ LNKESAYV ASEH
# Best at 20 METHOSKKYOT PJ LNKESAYV ASEH
# Best at 21 METHOSKKYOT PJ LNKESAJP ASEH
# Best at 22 METHOSKKYIT PJ LNKESAYV ASEH
# Best at 23 METHOSKKYIT PJ LNKESAYV ASEH
# Best at 24 METHOSKKYIT PJ LNKESAJP ASEH
# Best at 25 METHOSKKYIT PJ LNKESAJP ASEH
# Best at 26 METHOSKKYIT PJ LNKESAYV ASEH
# Best at 27 METHOSKKYIT PJ LNKESAYV ASEH
# Best at 28 METHOSKKYIT PJ LNKESAYV ASEH
# Best at 29 METHOSKKYIT PS LNKESAJV ASEH
# Best at 30 METHOSKKYIT PS LNKESAJV ASEH
# Best at 31 METHOSKKYIT PS LNKESAJP ASEH
# Best at 32 METHOSKKYIT PS LNKESAYV ASEH
# Best at 33 METHOSKKYIT PS LIKESAJV ASEH
# Best at 34 METHOSKKYIT PS LIKESAJV ASEH
# Best at 35 METHOSKKYIT PS LIKESAJV ASEH
# Best at 36 METHOSKKYIT PS LIKESAJV ASEH
# Best at 37 METHOSKKYIT PS LIKESAJV ASEH
# Best at 38 METHOSKKKIT PS LIKESAJV ASEH
# Best at 39 METHOSKKYIT PS LIKESAJV ASEH
# Best at 40 METHOSKKYIT PS LIKESAJV ASEH
# Best at 41 METHOSKKYIT PS LIKESAJV ASEH
# Best at 42 METHPSKKYIT PS LIKESAJV ASEH
# Best at 43 METHOSKKYIT PS LIKESAJV ASEH
# Best at 44 METHOSKKYIT PS LIKESAJV ASEH
# Best at 45 METHESKKYIT PS LIKESAJV ASEH
# Best at 46 METHOSKKYIT PS LIKESAJV ASEH
# Best at 47 METHOSKKYIT PS LIKESAJV ASEH
# Best at 48 METHOSKKYIT PS LIKESAJV ASEH
# Best at 49 METHOSKKYIT PS LIKESAJV ASEH
# Best at 50 METHOSKKYIT PS LIKESAJV ASEH
# Best at 51 METHOSKKYIT ZS LIKESAJV ASEH
# Best at 52 METHOSKKYIT PS LIKESAJV ASEH
# Best at 53 METHESKKYIT ZS LIKESAJVXASEH
# Best at 54 METHOSKKYIT PS LIKESAJV ASEH
# Best at 55 METHOSKQYIT PS LIKESAKV ASEH
# Best at 56 METHOSKQYIT PS LIKEZA VXASEH
# Best at 57 METHOSKQYIT PS LIKEZA V ASEH
# Best at 58 METHOSKKYIT PS LIKEZA VXASEH
# Best at 59 METHOSKKYIT PS LIKEZA V ASEH
# Best at 60 METHOSKKYIT PS LIKEZA VXASEH
# Best at 61 METHOSKKYIT PS LIKEZA V ASEH
# Best at 62 METHOSKKYIT PS LIKEZA VXASEH
# Best at 63 METHOSKKYIT PS LIKEZA VXASEH
# Best at 64 METHOSKKKIT PS LIKESA V ASEH
# Best at 65 METHOSKKYIT PS LIKEZA V ASEH
# Best at 66 METHOSKKYIT PS LIKEZA VXASEH
# Best at 67 METHOSKKYIT PS LIKEZA V ASEH
# Best at 68 METHOSKKYIT PS LIKEZA VXASEH
# Best at 69 METHOSKKYIT PS LIKEZA VXASEH
# Best at 70 METHOSKKYIT PS LIKEZA V ASEH
# Best at 71 METHOSKKYIT PS LIKEZA V ASEH
# Best at 72 METHOSKKYIT PS LIKEZA V ASEH
# Best at 73 METHOSKKYIT PS LIKEZA VXASEH
# Best at 74 METHOSKKYIT PS LIKEZA VXASEH
# Best at 75 METHOSKKYIT PS LIKEZA V ASEH
# Best at 76 METHOSKKYIT PS LIKEZA VXASEH
# Best at 77 METHOSKK IT PS LIKEZA VVASEH
# Best at 78 METHOSKK IT PS LIKEZA VVASEH
# Best at 79 METHOSKK IT PS LIKEZA VXASEH
# Best at 80 METHOSKK IT PS LIKEZA VVASEH
# Best at 81 METHOSKK IT PS LIKEZA VVASEH
# Best at 82 METHOSKK IT PS LIKEZA VVASEP
# Best at 83 METHOSKK IT PS LIKEZA VXASEH
# Best at 84 METHOSKK IT PS LIKEZA VXASEH
# Best at 85 METHOSKK IT PS LIKEZA VVASEH
# Best at 86 METHOSKK IT PS LIKEZA VXASEH
# Best at 87 METHOGKK IT PS LIKEZA VXASEH
# Best at 88 METHOGKS IT PS LIKEZA VXASEH
# Best at 89 METHOGKS IT PS LIKESA VXASEH
# Best at 90 METHOGKS IT PS LIKEZA WXASEH
# Best at 91 METHOGKS IT PS LIKEZA WXASEH
# Best at 92 METHOGKS IT PS LIKEZA WXASEH
# Best at 93 METHOGKS IT PS LIKEZA WXASEH
# Best at 94 METHONKS IT PS LIKEZA WXASEH
# Best at 95 METHONKS IT PS LIKEZA WXASEH
# Best at 96 METHONKS IT PS LIKESA WXASEH
# Best at 97 METHONKS IT PS LIKEZA WXASEH
# Best at 98 METHONKS IT PS LIKESA WXASEH
# Best at 99 METHONKS IT PS LIKEZA WXASEH
# Best at 100 METHONKS IT PS LIKEZA WXASEH
# Best at 101 METHONKS IT PS LIKESA WXASED
# Best at 102 METHONKS IT PS LIKEZA WXASEH
# Best at 103 METHONKS IT PS LIKEZA WXASEH
# Best at 104 METHONKS IT PS LIKEZA WXASEH
# Best at 105 METHONKS IT PS LIKEZA WXASEH
# Best at 106 METHONKS IT IS LIKEZA WXASEH
# Best at 107 METHONKS IT IS LIKEZA WXASEH
# Best at 108 METHINKS IT IS LIKEZA WXASED
# Best at 109 METHINKS IT IS LIKEZA WXASED
# Best at 110 METHINKS IT IS LIKEZA WXASEH
# Best at 111 METHINKS IT IS LIKESA WXASEH
# Best at 112 METHINKS IT IS LIKEZA WXASEH
# Best at 113 METHINKS IT IS LIKEZA WXASEH
# Best at 114 METHINKS IT IS LIKEZA WXASEH
# Best at 115 METHINKS IT IS LIKESA WXASET
# Best at 116 METHINKS IT IS LIKEZA WXASEH
# Best at 117 METHINKS IT IS LIKEZA WXASEH
# Best at 118 METHINKS IT IS LIKEZA WXASEH
# Best at 119 METHINKS IT IS LIKEZA WXASEH
# Best at 120 METHINKS IT IS LIKEZA WXASEH
# Best at 121 METHINKS IT IS LIKEZA WXASEH
# Best at 122 METHINKS IT IS LIKEZA WXASEH
# Best at 123 METHINKS IT IS LIKESA WXASEH
# Best at 124 METHINKS IT IS LIKE A WXASEH
# Best at 125 METHINKS IT IS LIKE A WXASEH
# Best at 126 METHINKS IT IS LIKE A WXASEH
# Best at 127 METHINKS IT IS LIKE A WXASEH
# Best at 128 METHINKS IT IS LIKE A WXASEH
# Best at 129 METHINKS IT IS LIKE A WXASEH
# Best at 130 METHINKS IT IS LIKE A WXASEH
# Best at 131 METHINKS IT IS LIKE A WXASEH
# Best at 132 METHINKS IT IS LIKE A WXASEH
# Best at 133 METHINKS IT IS LIKE A WXASEH
# Best at 134 METHINKS IT IS LIKE A WXASEH
# Best at 135 METHINKS IT IS LIKE A WXASEH
# Best at 136 METHINKS IT IS LIKE A WXASEH
# Best at 137 METHINKS IT IS LIKE A WXASEH
# Best at 138 METHINKS IT IS LIKE A WXASEH
# Best at 139 METHINKS IT IS LIKE A WXASEH
# Best at 140 METHINKS IT IS LIKE A WXASEH
# Best at 141 METHINKS IT IS LIKE A WXASEH
# Best at 142 METHINKS IT IS LIKE A WXASEH
# Best at 143 METHINKS IT IS LIKE A WXASEH
# Best at 144 METHINKS IT IS LIKE A WXASEH
# Best at 145 METHINKS IT IS LIKE A WXASEH
# Best at 146 METHINKS IT IS LIKE A WXASEH
# Best at 147 METHINKS IT IS LIKE A WXASEH
# Best at 148 METHINKS IT IS LIKE A WXASED
# Best at 149 METHINKS IT IS LIKE A WXASEH
# Best at 150 METHINKS IT IS LIKE A WXASEH
# Best at 151 METHINKS IT IS LIKE A WXASEH
# Best at 152 METHINKS IT IS LIKE A WXASEH
# Best at 153 METHINKS IT IS LIKE A WXASEH
# Best at 154 METHINKS IT IS LIKE A WXASEH
# Best at 155 METHINKS IT IS LIKE A WXASEL
# Best at 156 METHINKS IT IS LIKE A WXASEL
# Best at 157 METHINKS IT IS LIKE A WXASEL
# Best at 158 METHINKS IT IS LIKE A WXASEL
# Best at 159 METHINKS IT IS LIKE A WXASEL
# Best at 160 METHINKS IT IS LIKE A WXASEL
# Best at 161 METHINKS IT IS LIKE A WXASEL
# Best at 162 METHINKS IT IS LIKE A WXASEL
# Best at 163 METHINKS IT IS LIKE A WXASEL
# Best at 164 METHINKS IT IS LIKE A WEASEL
# Best at 165 METHINKS IT IS LIKE A WEASEL
# Best at 166 METHINKS IT IS LIKE A WEASEL
# Best at 167 METHINKS IT IS LIKE A WEASEL
# Best at 168 METHINKS IT IS LIKE A WEASEL
# Best at 169 METHINKS IT IS LIKE A WEASEL
# Best at 170 METHINKS IT IS LIKE A WEASEL
# Best at 171 METHINKS IT IS LIKE A WEASEL
# Best at 172 METHINKS IT IS LIKE A WEASEL
# Best at 173 METHINKS IT IS LIKE A WEASEL
# Best at 174 METHINKS IT IS LIKE A WEASEL
# Best at 175 METHINKS IT IS LIKE A WEASEL
# Best at 176 METHINKS IT IS LIKE A WEASEL
# Best at 177 METHINKS IT IS LIKE A WEASEL
# Best at 178 METHINKS IT IS LIKE A WEASEL
# Best at 179 METHINKS IT IS LIKE A WEASEL
# Best at 180 METHINKS IT IS LIKE A WEASEL
# Best at 181 METHINKS IT IS LIKE A WEASEL
# Best at 182 METHINKS IT IS LIKE A WEASEL
# Best at 183 METHINKS IT IS LIKE A WEASEL
# Best at 184 METHINKS IT IS LIKE A WEASEL
# Best at 185 METHINKS IT IS LIKE A WEASEL
# Best at 186 METHINKS IT IS LIKE A WEASEL
# Best at 187 METHINKS IT IS LIKE A WEASEL
# Best at 188 METHINKS IT IS LIKE A WEASEL
# Best at 189 METHINKS IT IS LIKE A WEASEL
# Best at 190 METHINKS IT IS LIKE A WEASEL
# Best at 191 METHINKS IT IS LIKE A WEASEL
# Best at 192 METHINKS IT IS LIKE A WEASEL
# Best at 193 METHINKS IT IS LIKE A WEASEL
# Best at 194 METHINKS IT IS LIKE A WEASEL
# Best at 195 METHINKS IT IS LIKE A WEASEL
# Best at 196 METHINKS IT IS LIKE A WEASEL
# Best at 197 METHINKS IT IS LIKE A WEASEL
# Best at 198 METHINKS IT IS LIKE A WEASEL
# Best at 199 METHINKS IT IS LIKE A WEASEL
# Best at 200 METHINKS IT IS LIKE A WEASEL
# Best at 201 METHINKS IT IS LIKE A WEASEL
# Best at 202 METHINKS IT IS LIKE A WEASEL
# Best at 203 METHINKS IT IS LIKE A WEASEL
# Best at 204 METHINKS IT IS LIKE A WEASEL
# Best at 205 METHINKS IT IS LIKE A WEASEL
# Best at 206 METHINKS IT IS LIKE A WEASEL
# Best at 207 METHINKS IT IS LIKE A WEASEL
# Best at 208 METHINKS IT IS LIKE A WEASEL
# Best at 209 METHINKS IT IS LIKE A WEASEL
# Best at 210 METHINKS IT IS LIKE A WEASEL
# Best at 211 METHINKS IT IS LIKE A WEASEL
# Best at 212 METHINKS IT IS LIKE A WEASEL
# Best at 213 METHINKS IT IS LIKE A WEASEL
# Best at 214 METHINKS IT IS LIKE A WEASEL
# Best at 215 METHINKS IT IS LIKE A WEASEL
# Best at 216 METHINKS IT IS LIKE A WEASEL
# Best at 217 METHINKS IT IS LIKE A WEASEL
# Best at 218 METHINKS IT IS LIKE A WEASEL
# Best at 219 METHINKS IT IS LIKE A WEASEL
# Best at 220 METHINKS IT IS LIKE A WEASEL
# Best at 221 METHINKS IT IS LIKE A WEASEL
# Best at 222 METHINKS IT IS LIKE A WEASEL
# Best at 223 METHINKS IT IS LIKE A WEASEL
# Best at 224 METHINKS IT IS LIKE A WEASEL
# Best at 225 METHINKS IT IS LIKE A WEASEL
# Best at 226 METHINKS IT IS LIKE A WEASEL
# Best at 227 METHINKS IT IS LIKE A WEASEL
# Best at 228 METHINKS IT IS LIKE A WEASEL
# Best at 229 METHINKS IT IS LIKE A WEASEL
# Best at 230 METHINKS IT IS LIKE A WEASEL
# Best at 231 METHINKS IT IS LIKE A WEASEL
# Best at 232 METHINKS IT IS LIKE A WEASEL
# Best at 233 METHINKS IT IS LIKE A WEASEL
# Best at 234 METHINKS IT IS LIKE A WEASEL
# Best at 235 METHINKS IT IS LIKE A WEASEL
# Best at 236 METHINKS IT IS LIKE A WEASEL
# Best at 237 METHINKS IT IS LIKE A WEASEL
# Best at 238 METHINKS IT IS LIKE A WEASEL
# Best at 239 METHINKS IT IS LIKE A WEASEL
# Best at 240 METHINKS IT IS LIKE A WEASEL
# Best at 241 METHINKS IT IS LIKE A WEASEL
# Best at 242 METHINKS IT IS LIKE A WEASEL
# Best at 243 METHINKS IT IS LIKE A WEASEL
# Best at 244 METHINKS IT IS LIKE A WEASEL
# Best at 245 METHINKS IT IS LIKE A WEASEL
# Best at 246 METHINKS IT IS LIKE A WEASEL
# Best at 247 METHINKS IT IS LIKE A WEASEL
# Best at 248 METHINKS IT IS LIKE A WEASEL
# Best at 249 METHINKS IT IS LIKE A WEASEL
# Best at 250 METHINKS IT IS LIKE A WEASEL
# Best at 251 METHINKS IT IS LIKE A WEASEL
# Best at 252 METHINKS IT IS LIKE A WEASEL
# Best at 253 METHINKS IT IS LIKE A WEASEL
# Best at 254 METHINKS IT IS LIKE A WEASEL
# Best at 255 METHINKS IT IS LIKE A WEASEL
# Best at 256 METHINKS IT IS LIKE A WEASEL
# Best at 257 METHINKS IT IS LIKE A WEASEL
# Best at 258 METHINKS IT IS LIKE A WEASEL
# Best at 259 METHINKS IT IS LIKE A WEASEL
# Best at 260 METHINKS IT IS LIKE A WEASEL
# Best at 261 METHINKS IT IS LIKE A WEASEL
# Best at 262 METHINKS IT IS LIKE A WEASEL
# Best at 263 METHINKS IT IS LIKE A WEASEL
# Best at 264 METHINKS IT IS LIKE A WEASEL
# Best at 265 METHINKS IT IS LIKE A WEASEL
# Best at 266 METHINKS IT IS LIKE A WEASEL
# Best at 267 METHINKS IT IS LIKE A WEASEL
# Best at 268 METHINKS IT IS LIKE A WEASEL
# Best at 269 METHINKS IT IS LIKE A WEASEL
# Best at 270 METHINKS IT IS LIKE A WEASEL
# Best at 271 METHINKS IT IS LIKE A WEASEL
# Best at 272 METHINKS IT IS LIKE A WEASEL
# Best at 273 METHINKS IT IS LIKE A WEASEL
# Best at 274 METHINKS IT IS LIKE A WEASEL
# Best at 275 METHINKS IT IS LIKE A WEASEL
# Best at 276 METHINKS IT IS LIKE A WEASEL
# Best at 277 METHINKS IT IS LIKE A WEASEL
# Best at 278 METHINKS IT IS LIKE A WEASEL
# Best at 279 METHINKS IT IS LIKE A WEASEL
# Best at 280 METHINKS IT IS LIKE A WEASEL
# Best at 281 METHINKS IT IS LIKE A WEASEL
# Best at 282 METHINKS IT IS LIKE A WEASEL
# Best at 283 METHINKS IT IS LIKE A WEASEL
# Best at 284 METHINKS IT IS LIKE A WEASEL
# Best at 285 METHINKS IT IS LIKE A WEASEL
# Best at 286 METHINKS IT IS LIKE A WEASEL
# Best at 287 METHINKS IT IS LIKE A WEASEL
# Best at 288 METHINKS IT IS LIKE A WEASEL
# Best at 289 METHINKS IT IS LIKE A WEASEL
# Best at 290 METHINKS IT IS LIKE A WEASEL
# Best at 291 METHINKS IT IS LIKE A WEASEL
# Best at 292 METHINKS IT IS LIKE A WEASEL
# Best at 293 METHINKS IT IS LIKE A WEASEL
# Best at 294 METHINKS IT IS LIKE A WEASEL
# Best at 295 METHINKS IT IS LIKE A WEASEL
# Best at 296 METHINKS IT IS LIKE A WEASEL
# Best at 297 METHINKS IT IS LIKE A WEASEL
# Best at 298 METHINKS IT IS LIKE A WEASEL
# Best at 299 METHINKS IT IS LIKE A WEASEL
# Best at 300 METHINKS IT IS LIKE A WEASEL
# Best at 301 METHINKS IT IS LIKE A WEASEL
# Best at 302 METHINKS IT IS LIKE A WEASEL
# Best at 303 METHINKS IT IS LIKE A WEASEL
# Best at 304 METHINKS IT IS LIKE A WEASEL
# Best at 305 METHINKS IT IS LIKE A WEASEL
# Best at 306 METHINKS IT IS LIKE A WEASEL
# Best at 307 METHINKS IT IS LIKE A WEASEL
# Best at 308 METHINKS IT IS LIKE A WEASEL
# Best at 309 METHINKS IT IS LIKE A WEASEL
# Best at 310 METHINKS IT IS LIKE A WEASEL
# Best at 311 METHINKS IT IS LIKE A WEASEL
# Best at 312 METHINKS IT IS LIKE A WEASEL
# Best at 313 METHINKS IT IS LIKE A WEASEL
# Best at 314 METHINKS IT IS LIKE A WEASEL
# Best at 315 METHINKS IT IS LIKE A WEASEL
# Best at 316 METHINKS IT IS LIKE A WEASEL
# Best at 317 METHINKS IT IS LIKE A WEASEL
# Best at 318 METHINKS IT IS LIKE A WEASEL
# Best at 319 METHINKS IT IS LIKE A WEASEL
# Best at 320 METHINKS IT IS LIKE A WEASEL
# Best at 321 METHINKS IT IS LIKE A WEASEL
# Best at 322 METHINKS IT IS LIKE A WEASEL
# Best at 323 METHINKS IT IS LIKE A WEASEL
# Best at 324 METHINKS IT IS LIKE A WEASEL
# Best at 325 METHINKS IT IS LIKE A WEASEL
# Best at 326 METHINKS IT IS LIKE A WEASEL
# Best at 327 METHINKS IT IS LIKE A WEASEL
# Best at 328 METHINKS IT IS LIKE A WEASEL
# Best at 329 METHINKS IT IS LIKE A WEASEL
# Best at 330 METHINKS IT IS LIKE A WEASEL
# Best at 331 METHINKS IT IS LIKE A WEASEL
# Best at 332 METHINKS IT IS LIKE A WEASEL
# Best at 333 METHINKS IT IS LIKE A WEASEL
# Best at 334 METHINKS IT IS LIKE A WEASEL
# Best at 335 METHINKS IT IS LIKE A WEASEL
# Best at 336 METHINKS IT IS LIKE A WEASEL
# Best at 337 METHINKS IT IS LIKE A WEASEL
# Best at 338 METHINKS IT IS LIKE A WEASEL
# Best at 339 METHINKS IT IS LIKE A WEASEL
# Best at 340 METHINKS IT IS LIKE A WEASEL
# Best at 341 METHINKS IT IS LIKE A WEASEL
# Best at 342 METHINKS IT IS LIKE A WEASEL
# Best at 343 METHINKS IT IS LIKE A WEASEL
# Best at 344 METHINKS IT IS LIKE A WEASEL
# Best at 345 METHINKS IT IS LIKE A WEASEL
# Best at 346 METHINKS IT IS LIKE A WEASEL
# Best at 347 METHINKS IT IS LIKE A WEASEL
# Best at 348 METHINKS IT IS LIKE A WEASEL
# Best at 349 METHINKS IT IS LIKE A WEASEL
# Best at 350 METHINKS IT IS LIKE A WEASEL
# Best at 351 METHINKS IT IS LIKE A WEASEL
# Best at 352 METHINKS IT IS LIKE A WEASEL
# Best at 353 METHINKS IT IS LIKE A WEASEL
# Best at 354 METHINKS IT IS LIKE A WEASEL
# Best at 355 METHINKS IT IS LIKE A WEASEL
# Best at 356 METHINKS IT IS LIKE A WEASEL
# Best at 357 METHINKS IT IS LIKE A WEASEL
# Best at 358 METHINKS IT IS LIKE A WEASEL
# Best at 359 METHINKS IT IS LIKE A WEASEL
# Best at 360 METHINKS IT IS LIKE A WEASEL
# Best at 361 METHINKS IT IS LIKE A WEASEL
# Best at 362 METHINKS IT IS LIKE A WEASEL
# Best at 363 METHINKS IT IS LIKE A WEASEL
# Best at 364 METHINKS IT IS LIKE A WEASEL
# Best at 365 METHINKS IT IS LIKE A WEASEL
# Best at 366 METHINKS IT IS LIKE A WEASEL
# Best at 367 METHINKS IT IS LIKE A WEASEL
# Best at 368 METHINKS IT IS LIKE A WEASEL
# Best at 369 METHINKS IT IS LIKE A WEASEL
# Best at 370 METHINKS IT IS LIKE A WEASEL
# Best at 371 METHINKS IT IS LIKE A WEASEL
# Best at 372 METHINKS IT IS LIKE A WEASEL
# Best at 373 METHINKS IT IS LIKE A WEASEL
# Best at 374 METHINKS IT IS LIKE A WEASEL
# Best at 375 METHINKS IT IS LIKE A WEASEL
# Best at 376 METHINKS IT IS LIKE A WEASEL
# Best at 377 METHINKS IT IS LIKE A WEASEL
# Best at 378 METHINKS IT IS LIKE A WEASEL
# Best at 379 METHINKS IT IS LIKE A WEASEL
# Best at 380 METHINKS IT IS LIKE A WEASEL
# Best at 381 METHINKS IT IS LIKE A WEASEL
# Best at 382 METHINKS IT IS LIKE A WEASEL
# Best at 383 METHINKS IT IS LIKE A WEASEL
# Best at 384 METHINKS IT IS LIKE A WEASEL
# Best at 385 METHINKS IT IS LIKE A WEASEL
# Best at 386 METHINKS IT IS LIKE A WEASEL
# Best at 387 METHINKS IT IS LIKE A WEASEL
# Best at 388 METHINKS IT IS LIKE A WEASEL
# Best at 389 METHINKS IT IS LIKE A WEASEL
# Best at 390 METHINKS IT IS LIKE A WEASEL
# Best at 391 METHINKS IT IS LIKE A WEASEL
# Best at 392 METHINKS IT IS LIKE A WEASEL
# Best at 393 METHINKS IT IS LIKE A WEASEL
# Best at 394 METHINKS IT IS LIKE A WEASEL
# Best at 395 METHINKS IT IS LIKE A WEASEL
# Best at 396 METHINKS IT IS LIKE A WEASEL
# Best at 397 METHINKS IT IS LIKE A WEASEL
# Best at 398 METHINKS IT IS LIKE A WEASEL
# Best at 399 METHINKS IT IS LIKE A WEASEL
# Best at 400 METHINKS IT IS LIKE A WEASEL
# Best at 401 METHINKS IT IS LIKE A WEASEL
# Best at 402 METHINKS IT IS LIKE A WEASEL
# Best at 403 METHINKS IT IS LIKE A WEASEL
# Best at 404 METHINKS IT IS LIKE A WEASEL
# Best at 405 METHINKS IT IS LIKE A WEASEL
# Best at 406 METHINKS IT IS LIKE A WEASEL
# Best at 407 METHINKS IT IS LIKE A WEASEL
# Best at 408 METHINKS IT IS LIKE A WEASEL
# Best at 409 METHINKS IT IS LIKE A WEASEL
# Best at 410 METHINKS IT IS LIKE A WEASEL
# Best at 411 METHINKS IT IS LIKE A WEASEL
# Best at 412 METHINKS IT IS LIKE A WEASEL
# Best at 413 METHINKS IT IS LIKE A WEASEL
# Best at 414 METHINKS IT IS LIKE A WEASEL
# Best at 415 METHINKS IT IS LIKE A WEASEL
# Best at 416 METHINKS IT IS LIKE A WEASEL
# Best at 417 METHINKS IT IS LIKE A WEASEL
# Best at 418 METHINKS IT IS LIKE A WEASEL
# Best at 419 METHINKS IT IS LIKE A WEASEL
# Best at 420 METHINKS IT IS LIKE A WEASEL
# Best at 421 METHINKS IT IS LIKE A WEASEL
# Best at 422 METHINKS IT IS LIKE A WEASEL
# Best at 423 METHINKS IT IS LIKE A WEASEL
# Best at 424 METHINKS IT IS LIKE A WEASEL
# Best at 425 METHINKS IT IS LIKE A WEASEL
# Best at 426 METHINKS IT IS LIKE A WEASEL
# Best at 427 METHINKS IT IS LIKE A WEASEL
# Best at 428 METHINKS IT IS LIKE A WEASEL
# Best at 429 METHINKS IT IS LIKE A WEASEL
# Best at 430 METHINKS IT IS LIKE A WEASEL
# Best at 431 METHINKS IT IS LIKE A WEASEL
# Best at 432 METHINKS IT IS LIKE A WEASEL
# Best at 433 METHINKS IT IS LIKE A WEASEL
# Best at 434 METHINKS IT IS LIKE A WEASEL
# Best at 435 METHINKS IT IS LIKE A WEASEL
# Best at 436 METHINKS IT IS LIKE A WEASEL
# Best at 437 METHINKS IT IS LIKE A WEASEL
# Best at 438 METHINKS IT IS LIKE A WEASEL
# Best at 439 METHINKS IT IS LIKE A WEASEL
# Best at 440 METHINKS IT IS LIKE A WEASEL
# Best at 441 METHINKS IT IS LIKE A WEASEL
# Best at 442 METHINKS IT IS LIKE A WEASEL
# Best at 443 METHINKS IT IS LIKE A WEASEL
# Best at 444 METHINKS IT IS LIKE A WEASEL
# Best at 445 METHINKS IT IS LIKE A WEASEL
# Best at 446 METHINKS IT IS LIKE A WEASEL
# Best at 447 METHINKS IT IS LIKE A WEASEL
# Best at 448 METHINKS IT IS LIKE A WEASEL
# Best at 449 METHINKS IT IS LIKE A WEASEL
# Best at 450 METHINKS IT IS LIKE A WEASEL
# Best at 451 METHINKS IT IS LIKE A WEASEL
# Best at 452 METHINKS IT IS LIKE A WEASEL
# Best at 453 METHINKS IT IS LIKE A WEASEL
# Best at 454 METHINKS IT IS LIKE A WEASEL
# Best at 455 METHINKS IT IS LIKE A WEASEL
# Best at 456 METHINKS IT IS LIKE A WEASEL
# Best at 457 METHINKS IT IS LIKE A WEASEL
# Best at 458 METHINKS IT IS LIKE A WEASEL
# Best at 459 METHINKS IT IS LIKE A WEASEL
# Best at 460 METHINKS IT IS LIKE A WEASEL
# Best at 461 METHINKS IT IS LIKE A WEASEL
# Best at 462 METHINKS IT IS LIKE A WEASEL
# Best at 463 METHINKS IT IS LIKE A WEASEL
# Best at 464 METHINKS IT IS LIKE A WEASEL
# Best at 465 METHINKS IT IS LIKE A WEASEL
# Best at 466 METHINKS IT IS LIKE A WEASEL
# Best at 467 METHINKS IT IS LIKE A WEASEL
# Best at 468 METHINKS IT IS LIKE A WEASEL
# Best at 469 METHINKS IT IS LIKE A WEASEL
# Best at 470 METHINKS IT IS LIKE A WEASEL
# Best at 471 METHINKS IT IS LIKE A WEASEL
# Best at 472 METHINKS IT IS LIKE A WEASEL
# Best at 473 METHINKS IT IS LIKE A WEASEL
# Best at 474 METHINKS IT IS LIKE A WEASEL
# Best at 475 METHINKS IT IS LIKE A WEASEL
# Best at 476 METHINKS IT IS LIKE A WEASEL
# Best at 477 METHINKS IT IS LIKE A WEASEL
# Best at 478 METHINKS IT IS LIKE A WEASEL
# Best at 479 METHINKS IT IS LIKE A WEASEL
# Best at 480 METHINKS IT IS LIKE A WEASEL
# Best at 481 METHINKS IT IS LIKE A WEASEL
# Best at 482 METHINKS IT IS LIKE A WEASEL
# Best at 483 METHINKS IT IS LIKE A WEASEL
# Best at 484 METHINKS IT IS LIKE A WEASEL
# Best at 485 METHINKS IT IS LIKE A WEASEL
# Best at 486 METHINKS IT IS LIKE A WEASEL
# Best at 487 METHINKS IT IS LIKE A WEASEL
# Best at 488 METHINKS IT IS LIKE A WEASEL
# Best at 489 METHINKS IT IS LIKE A WEASEL
# Best at 490 METHINKS IT IS LIKE A WEASEL
# Best at 491 METHINKS IT IS LIKE A WEASEL
# Best at 492 METHINKS IT IS LIKE A WEASEL
# Best at 493 METHINKS IT IS LIKE A WEASEL
# Best at 494 METHINKS IT IS LIKE A WEASEL
# Best at 495 METHINKS IT IS LIKE A WEASEL
# Best at 496 METHINKS IT IS LIKE A WEASEL
# Best at 497 METHINKS IT IS LIKE A WEASEL
# Best at 498 METHINKS IT IS LIKE A WEASEL
# Best at 499 METHINKS IT IS LIKE A WEASEL
# ('METHINKS IT IS LIKE A WEASEL', 0)
